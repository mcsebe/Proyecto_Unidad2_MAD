# %% [markdown]
# # TAREA MAD ANALISIS DE NOTICIAS: EDUCACIÓN

# %% [markdown]
# ## 1) Elegir palabras claves para construir un dataset sobre cierta(s) temática(s)

# %% [markdown]
# ### Las palabras claves para realizar el analisis serán: *"educativa", "educar", "escolar", "escuela", "escuelas", "alumno", "alumnos", "colegio", "colegios", "instituto", "institutos", "universidad", "universidades", "pedagogía", "educacción", "Universidad", "universitario", "maestro", "profesor", "maestros", "profesores"*

# %% [markdown]
# ## 2) Construir indicadores estadísticos para describir el dataset obtenido

# %% [markdown]
# ### Cantidad de noticias:

# %%
import pandas as pd
import spacy
import pandas as pd

# %%
data1 = r'C:/Users/joaqu/Desktop/Academia/MAGISTER/Mineria y aprendizaje con datos/CLASE 6/dataset_2020_latercera.csv'
data2 = r'C:/Users/joaqu/Desktop/Academia/MAGISTER/Mineria y aprendizaje con datos/CLASE 6/dataset_2021_latercera.csv'
data3 = r'C:/Users/joaqu/Desktop/Academia/MAGISTER/Mineria y aprendizaje con datos/CLASE 6/dataset_2022_latercera.csv'
data4 = r'C:/Users/joaqu/Desktop/Academia/MAGISTER/Mineria y aprendizaje con datos/CLASE 6/dataset_chile_latercera_2023.csv'

# Cargar los cuatro archivos CSV en DataFrames
df1 = pd.read_csv(data1)
df2 = pd.read_csv(data2)
df3 = pd.read_csv(data3)
df4 = pd.read_csv(data4)

# Unir los DataFrames en uno solo
#df_total = pd.concat([df1, df2, df3, df4])

# Guardar el DataFrame combinado en un nuevo archivo CSV
#df_total.to_csv('DFMAD.csv', index=False)

# %%
print(df1.shape[0])
print(df2.shape[0])
print(df3.shape[0])
print(df4.shape[0])
print(df.shape[0])
# Out:
# 28236
# 28236
# 24926
# 26989
# 108387

# %%
rutaCSV = r'C:/Users/joaqu/Desktop/Academia/MAGISTER/Mineria y aprendizaje con datos/CLASE 6/DFMAD.csv'
df = pd.read_csv(rutaCSV)

# %%
# Convertir la columna 'date' al tipo datetime
df['date'] = pd.to_datetime(df['date'], format='%b %d, %Y @ %H:%M:%S.%f')
# Formatear la columna 'date' al formato YYYY-MM-DD
df['date'] = df['date'].dt.strftime('%Y-%m-%d')
df
# Out:
#               date country media_outlet  \
# 0       2020-01-01   chile    latercera
# 1       2020-01-01   chile    latercera
# 2       2020-01-01   chile    latercera
# 3       2020-01-01   chile    latercera
# 4       2020-01-01   chile    latercera
# ...            ...     ...          ...
# 108382  2023-12-31   chile    latercera
# 108383  2023-12-31   chile    latercera
# 108384  2023-12-31   chile    latercera
# 108385  2023-12-31   chile    latercera
# 108386  2023-12-31   chile    latercera
#
#                                                     title  \
# 0       Con televisor, hervidor, un termo ventilador y...
# 1       Claudia López: la nueva alcaldesa ecologista d...
# 2       David Stern: la historia del comisionado de la...
# 3       Estados Unidos prohibió la venta de productos ...
# 4       Samsung y LG lanzarán refrigeradores inteligen...
# ...                                                   ...
# 108382  Jaime Gajardo, subsecretario de Justicia: “El ...
# ...

# %% [markdown]
# #### El total de noticias indexadas en el medio de "la tercera" son 108387.

# %%
palabras_clave = ["educativa", "educar", "escolar", "escuela", "escuelas", "alumno", "alumnos", "colegio", "colegios", "instituto", "institutos", "universidad", "universidades", "pedagogía", "educacción", "Universidad", "universitario", "maestro", "profesor", "maestros", "profesores"]

# %%
# Función para calcular la relevancia de una fila basada en las palabras clave
def calcular_relevancia(texto):
    relevancia = sum(1 for palabra in palabras_clave if palabra in texto)
    return relevancia

# %%
# Aplicar la función calcular_relevancia a cada fila y guardar el resultado en una nueva columna "relevancia"
df["relevancia"] = df["text"].apply(calcular_relevancia)

# Seleccionar las filas más relevantes
filas_mas_relevantes = df[df["relevancia"] > 0]

# Imprimir las filas más relevantes
filas_mas_relevantes.sort_values(by="relevancia", ascending=False)
# Out:
#               date country media_outlet  \
# 65047   2022-05-09   chile    latercera
# 13669   2020-07-09   chile    latercera
# 30824   2020-07-09   chile    latercera
# 24774   2020-11-17   chile    latercera
# 35091   2020-11-17   chile    latercera
# ...            ...     ...          ...
# 65146   2022-05-10   chile    latercera
# 65147   2022-05-10   chile    latercera
# 26221   2020-12-05   chile    latercera
# 65149   2022-05-10   chile    latercera
# 108382  2023-12-31   chile    latercera
#
#                                                     title  \
# 65047   ‘Seamos Comunidad’, la política de $22.500 mil...
# 13669         Profesores al borde de un ataque de nervios
# 30824         Profesores al borde de un ataque de nervios
# 24774   Mineduc proyecta que el 21% de colegios con 4°...
# 35091   Mineduc proyecta que el 21% de colegios con 4°...
# ...                                                   ...
# 65146   Expectación mundial por anuncio de asombroso d...
# ...

# %% [markdown]
# ### Las noticias resultantes del filtrado son 19568 de un total de 108387

# %% [markdown]
# ### Distribución en el tiempos(Total Noticias):

# %%
import matplotlib.pyplot as plt
df['date'] = pd.to_datetime(df['date'])

# Crear una nueva columna para el mes y el año
df['month_year'] = df['date'].dt.to_period('M')

# Contar la cantidad de datos por mes
month_counts = df['month_year'].value_counts().sort_index()
print(month_counts)
#Crear el histograma
plt.figure(figsize=(10, 6))
month_counts.plot(kind='bar')
plt.xlabel('Mes')
plt.ylabel('Cantidad de datos')
plt.title('Cantidad de datos por mes [TOTAL NOTICIAS]')
plt.xticks(rotation=45, fontsize=10)  # Ajustar el tamaño de las etiquetas del eje x
plt.tight_layout()  # Ajustar el layout para que las etiquetas no se corten
plt.show()
# Out:
# month_year
# 2020-01    5416
# 2020-02    3832
# 2020-03    4220
# 2020-04    4098
# 2020-05    3836
# 2020-06    4512
# 2020-07    5322
# 2020-08    5294
# 2020-09    4956
# 2020-10    5096
# 2020-11    5182
# 2020-12    4708
# 2022-01    2047
# 2022-02    1690
# 2022-03    2225
# 2022-04    1978
# 2022-05    2287
# 2022-06    2070
# 2022-07    2096
# 2022-08    2257
# 2022-09    2122
# 2022-10    1959
# 2022-11    2065
# 2022-12    2130
# 2023-01    2438
# 2023-02    2040
# 2023-03    2365
# 2023-04    1793
# 2023-05    2284
# 2023-06    2153
# 2023-07    2397
# 2023-08    2430
# 2023-09    2088
# 2023-10    2273
# 2023-11    2310
# 2023-12    2418
# Freq: M, Name: count, dtype: int64

# %% [markdown]
# ## Distribución tiempo (Noticias Educación)

# %%
filas_mas_relevantes['date'] = pd.to_datetime(filas_mas_relevantes['date'])

# Crear una nueva columna para el mes y el año
filas_mas_relevantes['month_year'] = filas_mas_relevantes['date'].dt.to_period('M')

# Contar la cantidad de datos por mes
month_counts = filas_mas_relevantes['month_year'].value_counts().sort_index()

#Crear el histograma
plt.figure(figsize=(10, 6))
month_counts.plot(kind='bar')
plt.xlabel('Mes')
plt.ylabel('Cantidad de datos')
plt.title('Cantidad de datos por mes [TOTAL NOTICIAS]')
plt.xticks(rotation=45, fontsize=10)  # Ajustar el tamaño de las etiquetas del eje x
plt.tight_layout()  # Ajustar el layout para que las etiquetas no se corten
plt.show()
# Out:
# C:\Users\joaqu\AppData\Local\Temp\ipykernel_16428\2722305671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filas_mas_relevantes['date'] = pd.to_datetime(filas_mas_relevantes['date'])
# C:\Users\joaqu\AppData\Local\Temp\ipykernel_16428\2722305671.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filas_mas_relevantes['month_year'] = filas_mas_relevantes['date'].dt.to_period('M')

# %% [markdown]
# ## Organizaciones y personas más mencionadas

# %%
df_muestra = df.sample(n=100, random_state=42)

# %%
import spacy

# Cargar el modelo de Spacy para el idioma que necesites (por ejemplo, español)
nlp = spacy.load("es_core_news_sm")

# Función para extraer entidades de tipo persona de un texto usando Spacy
def extract_person_entities(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "PER" and len(ent.text.split()) >= 2]

def extract_org_entities(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "ORG" and len(ent.text.split()) >= 2]

# Aplicar la función a cada fila de la columna "text" y guardar los resultados en una nueva columna
df_muestra["person_entities"] = df_muestra["text"].apply(extract_person_entities)
df_muestra["org_entities"] = df_muestra["text"].apply(extract_org_entities)

# %%
from tqdm import tqdm

# Aplicar la función a cada fila de la columna "text" y guardar los resultados en una nueva columna
tqdm.pandas()
df_muestra["person_entities"] = df_muestra["text"].progress_apply(extract_person_entities)
df_muestra["org_entities"] = df_muestra["text"].progress_apply(extract_org_entities)
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.17it/s]

# %%
df_muestra
# Out:
#              date country media_outlet  \
# 32062  2020-08-30   chile    latercera
# 50857  2020-08-18   chile    latercera
# 91992  2023-05-28   chile    latercera
# 83059  2023-01-22   chile    latercera
# 71645  2022-08-10   chile    latercera
# ...           ...     ...          ...
# 94226  2023-06-27   chile    latercera
# 107109 2023-12-15   chile    latercera
# 12450  2020-06-24   chile    latercera
# 42799  2020-10-22   chile    latercera
# 69473  2022-07-11   chile    latercera
#
#                                                     title  \
# 32062   Van Rysselberghe: “Puedo no votar porque creo ...
# 50857   Balance policial: Detenidos por infracciones s...
# 91992   “ Hace falta en todas las escuelas”: colegio e...
# 83059   La película live-action de Hot Wheels está ava...
# 71645   El adelanto con los primeros minutos de Tales ...
# ...                                                   ...
# 94226   Descubren un antiguo álbum fotográfico que rev...
# ...

# %% [markdown]
# ## POLARIDAD

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline

model_name = "finiteautomata/beto-sentiment-analysis"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# Out:
# C:\Users\joaqu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# C:\Users\joaqu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\joaqu\.cache\huggingface\hub\models--finiteautomata--beto-sentiment-analysis. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
for index, row in tqdm(df_muestra.iterrows(), desc='Análisis de sentimiento', total=df_muestra.shape[0]):
    
    sentiment_value = sentiment_pipeline(row['title'])
    
    # Insertamos en dataframe
    df_muestra.at[index, "prediction"] = sentiment_value[0].get('label')
    df_muestra.at[index, "score"] = sentiment_value[0].get('score')
# Out:
# Análisis de sentimiento: 100%|███████████████████████████████████████████████████████| 100/100 [00:20<00:00,  4.91it/s]

# %%
df_muestra
# Out:
#              date country media_outlet  \
# 32062  2020-08-30   chile    latercera
# 50857  2020-08-18   chile    latercera
# 91992  2023-05-28   chile    latercera
# 83059  2023-01-22   chile    latercera
# 71645  2022-08-10   chile    latercera
# ...           ...     ...          ...
# 94226  2023-06-27   chile    latercera
# 107109 2023-12-15   chile    latercera
# 12450  2020-06-24   chile    latercera
# 42799  2020-10-22   chile    latercera
# 69473  2022-07-11   chile    latercera
#
#                                                     title  \
# 32062   Van Rysselberghe: “Puedo no votar porque creo ...
# 50857   Balance policial: Detenidos por infracciones s...
# 91992   “ Hace falta en todas las escuelas”: colegio e...
# 83059   La película live-action de Hot Wheels está ava...
# 71645   El adelanto con los primeros minutos de Tales ...
# ...                                                   ...
# 94226   Descubren un antiguo álbum fotográfico que rev...
# ...

# %% [markdown]
# ## 3) Proponer un método para clasificar las noticias según
