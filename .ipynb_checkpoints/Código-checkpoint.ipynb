# %%
# Primero decir que porcentaje de noticias que continen las palabras ... son de Valdivia y la distribución de esas noticias en Chile
# Centrarse en Valdivia
# Análisis temporal y de polaridad de las noticias de estudiantes en Valdivia

#¿Cuales son los temas más recurrentes 2023?
#¿Cuales son las egiones?
#¿Existen patrones geográficos?
#Análisis temporal: a lo lago de los años
#¿Como varía la polaridad de las noticias en las diferentes regiones?

# %% [markdown]
# Tarea:
#
# 1) Elegir palabras claves para construir un dataset sobre cierta(s) temática(s)
#
# 2) Construir indicadores estadísticos para describir el dataset obtenido
#    - Cantidad de noticias
#    - Distribución en el tiempo
#    - Polaridad (connotación positiva, negativa o neutra) de las noticias
#    - Organizaciones y personas más mencionadas
#
# 3) Proponer un método para clasificar las noticias según:
#    - su(s) region(es)
#    - su(s) comuna(s)
#
# 4) A partir de una muestra, evaluar el porcentaje de exactitud de su método. ¿Cuáles son las limitaciones de su método?
#
# 5) Mostrar la distribución de las noticias según su comuna y región

# %% [markdown]
# # 1- Temática
#
# La temática escogida son las noticias de educación del medio "La tercera". Las palabras claves para realizar el analisis serán: *"educativa", "educar", "escolar", "escuela", "escuelas", "alumno", "alumnos", "colegio", "colegios", "universidad", "universidades", "pedagogía", "educacción", "Universidad", "universitario", "universitarios", "profesor" y "profesores"*. Estas se buscarán en las 5 primeras frases de cada noticia.

# %% [markdown]
# # 2- Indicadores estadísticos
# ## Cantidad de noticias

# %%
import pandas as pd
df_2020 = pd.read_csv('./Datos/dataset_2020_latercera.csv')
df_2021 = pd.read_csv('./Datos/dataset_2021_latercera_corregido.csv')
df_2022 = pd.read_csv('./Datos/dataset_2022_latercera.csv')
df_2023 = pd.read_csv('./Datos/dataset_chile_latercera_2023.csv')


# Unir los DataFrames en uno solo
df_total = pd.concat([df_2020, df_2021, df_2022, df_2023])

# Convertir la columna 'date' al tipo datetime
df_total['date'] = pd.to_datetime(df_total['date'], format='%b %d, %Y @ %H:%M:%S.%f')

# Formatear la columna 'date' al formato YYYY-MM-DD
df_total['date'] = df_total['date'].dt.strftime('%Y-%m-%d')


print(df_2020.shape[0])
print(df_2021.shape[0])
print(df_2022.shape[0])
print(df_2023.shape[0])
print(df_total.shape[0])
# Out:
# 28236
# 18539
# 24926
# 26989
# 98690

# %% [markdown]
# **El total de noticias indexadas en el medio de "la tercera" son 98690.**

# %%
palabras_clave = ["educativa", "educar", "escolar", "escuela", "escuelas", "alumno", "alumnos", "colegio", "colegios", "universidad", "universidades", "pedagogía", "educacción", "Universidad", "universitario", "universitarios", "profesor", "profesores"]

# Función para calcular la relevancia de una fila basada en las palabras clave
def calcular_relevancia(texto):
    frases = texto.split('.')[:5]
    text=""
    for frase in frases:
        text=text+frase+"."
    relevancia = sum(1 for palabra in palabras_clave if palabra in text)
    return relevancia

# Aplicar la función calcular_relevancia a cada fila y guardar el resultado en una nueva columna "relevancia"
df_total["relevancia"] = df_total["text"].apply(calcular_relevancia)
df_filtr = df_total[df_total["relevancia"] > 0].copy()

# Luego, ordena el DataFrame filtrado por la columna "relevancia"
df_ordenado = df_filtr.sort_values(by="relevancia", ascending=False)
df_ordenado
# Out:
#              date country media_outlet  \
# 17309  2020-08-20   chile    latercera
# 1020   2023-01-15   chile    latercera
# 14360  2021-03-18   chile    latercera
# 22091  2023-10-29   chile    latercera
# 2084   2020-01-24   chile    latercera
# ...           ...     ...          ...
# 10351  2021-11-10   chile    latercera
# 10231  2021-01-10   chile    latercera
# 10227  2021-01-27   chile    latercera
# 10221  2021-01-31   chile    latercera
# 26926  2023-12-30   chile    latercera
#
#                                                    title  \
# 17309  Más de 40 colegios en Alemania registran casos...
# 1020   Tiemblan las tareas y ensayos: universidades p...
# 14360  EE.UU. disminuye distancia mínima entre estudi...
# 22091  Presidente del Colegio de Profesores de Atacam...
# 2084   Estudiantes realizarán encuentro para proponer...
# ...                                                  ...
# 10351  Rumbo a un tercer mandato: Partido Comunista C...
# 10231  Astrónomos captan desde Chile y por primera ve...
# 10227         ¿Es buena idea tomarse vacaciones en casa?
# 10221  Estudio afirma que coronavirus puede dejar est...
# 26926  Árbol cae sobre la primera locomotora de Chile...
#
#                                                     text  \
# 17309  Al menos 41 colegios en Alemania han registran...
# 1020   Con el paso de los años, las técnicas para cop...
# 14360  El Gobierno estadounidense actualizó el vierne...
# 22091  La delicada situación educativa que está vivie...
# 2084   A horas de que se rinda la segunda PSU, que al...
# ...                                                  ...
# 10351  El Partido Comunista Chino (PCCh) ha concluido...
# 10231  Aunque las galaxias comienzan a “morir” cuando...
# 10227  Cuando ocurren periodos prolongados de confina...
# 10221  Dado que el nuevo coronavirus solo ha existido...
# 26926  En medio de los fuertes vientos y las tormenta...
#
#                                                      url  relevancia
# 17309  https://www.latercera.com/mundo/noticia/mas-de...          10
# 1020   https://www.latercera.com/tendencias/noticia/t...           9
# 14360  https://www.latercera.com/que-pasa/noticia/eeu...           9
# 22091  https://www.latercera.com/nacional/noticia/pre...           9
# 2084   https://www.latercera.com/nacional/noticia/est...           9
# ...                                                  ...         ...
# 10351  https://www.latercera.com/mundo/noticia/rumbo-...           1
# 10231  https://www.latercera.com/que-pasa/noticia/ast...           1
# 10227  https://www.latercera.com/que-pasa/noticia/es-...           1
# 10221  https://www.latercera.com/que-pasa/noticia/est...           1
# 26926  https://www.latercera.com/nacional/noticia/arb...           1
#
# [7254 rows x 7 columns]

# %% [markdown]
# **Las noticias resultantes del filtrado son 7254 de un total de 98690, lo que corresponde a un 7.35% de las noticias totales**

# %% [markdown]
# ## Distribución en el tiempo

# %% [markdown]
# ### Distribución en el tiempos(Total Noticias):

# %%
import matplotlib.pyplot as plt
df_total['date'] = pd.to_datetime(df_total['date'])

# Crear una nueva columna para el mes y el año
df_total['month_year'] = df_total['date'].dt.to_period('M')

# Contar la cantidad de datos por mes
month_counts = df_total['month_year'].value_counts().sort_index()
#Crear el histograma
plt.figure(figsize=(10, 6))
month_counts.plot(kind='bar')
plt.xlabel('Mes')
plt.ylabel('Cantidad de datos')
plt.title('Cantidad de datos por mes [TOTAL NOTICIAS]')
plt.xticks(rotation=45, fontsize=10)  # Ajustar el tamaño de las etiquetas del eje x
plt.tight_layout()  # Ajustar el layout para que las etiquetas no se corten
plt.show()

# %%
month_counts.describe()
# Out:
# count      48.000000
# mean     2056.041667
# std       413.139303
# min       870.000000
# 25%      1908.500000
# 50%      2103.000000
# 75%      2321.000000
# max      2708.000000
# Name: count, dtype: float64

# %% [markdown]
# ### Distribución tiempo (Noticias Educación)

# %%
df_filtr['date'] = pd.to_datetime(df_filtr['date'])

# Crear una nueva columna para el mes y el año
df_filtr['month_year'] = df_filtr['date'].dt.to_period('M')

# Contar la cantidad de datos por mes
month_counts = df_filtr['month_year'].value_counts().sort_index()

#Crear el histograma
plt.figure(figsize=(10, 6))
month_counts.plot(kind='bar')
plt.xlabel('Mes')
plt.ylabel('Cantidad de datos')
plt.title('Cantidad de datos por mes [TOTAL NOTICIAS]')
plt.xticks(rotation=45, fontsize=10)  # Ajustar el tamaño de las etiquetas del eje x
plt.tight_layout()  # Ajustar el layout para que las etiquetas no se corten
plt.show()

# %%
month_counts.describe()
# Out:
# count     48.00000
# mean     151.12500
# std       38.56557
# min       94.00000
# 25%      122.00000
# 50%      144.00000
# 75%      179.75000
# max      249.00000
# Name: count, dtype: float64

# %% [markdown]
# ## POLARIDAD

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline
from tqdm import tqdm

model_name = "finiteautomata/beto-sentiment-analysis"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
for index, row in tqdm(df_filtr.iterrows(), desc='Análisis de sentimiento', total=df_filtr.shape[0]):
    
    sentiment_value = sentiment_pipeline(row['title'])
    
    # Insertamos en dataframe
    df_filtr.at[index, "prediction"] = sentiment_value[0].get('label')
    df_filtr.at[index, "score"] = sentiment_value[0].get('score')
# Out:
# Análisis de sentimiento: 100%|█████████████████████████████████████████████████████| 7254/7254 [08:51<00:00, 13.65it/s]

# %%
df_filtr['prediction'].value_counts()
# Out:
# prediction
# NEU    4087
# NEG    2590
# POS     577
# Name: count, dtype: int64

# %%
# Agrupar los datos por mes y valor de 'prediction' y contar las ocurrencias
grouped = df_filtr.groupby(['month_year', 'prediction']).size().unstack(fill_value=0)

# Crear el histograma
plt.figure(figsize=(12, 8))

# Crear el gráfico de barras apiladas
grouped.plot(kind='bar', stacked=True, ax=plt.gca(), color={'POS': '#70D453', 'NEG': '#EB5A5A', 'NEU': '#536DD4'})

plt.xlabel('Mes')
plt.ylabel('Cantidad de datos')
plt.title('Cantidad de datos por mes y predicción [TOTAL NOTICIAS]')
plt.xticks(rotation=45, fontsize=10)  # Ajustar el tamaño de las etiquetas del eje x
plt.legend(title='Prediction')
plt.tight_layout()  # Ajustar el layout para que las etiquetas no se corten

plt.show()

# %%
grouped['%NEG'] = grouped['NEG']/(grouped['NEG']+grouped['NEU']+grouped['POS']) * 100
grouped['%POS'] = grouped['POS']/(grouped['NEG']+grouped['NEU']+grouped['POS']) * 100
grouped['%NEU'] = grouped['NEU']/(grouped['NEG']+grouped['NEU']+grouped['POS']) * 100

# %%
plt.figure(figsize=(12, 8))

grouped['%NEG'].plot(kind='line', marker='o', linestyle='-', color='#EB5A5A', label='%NEG')
grouped['%POS'].plot(kind='line', marker='o', linestyle='-', color='#70D453', label='%POS')
grouped['%NEU'].plot(kind='line', marker='o', linestyle='-', color='#536DD4', label='%NEU')

plt.xlabel('Mes')
plt.ylabel('Porcentaje')
plt.title('Porcentaje de NEG y POS por mes')
plt.xticks(rotation=45, fontsize=10)  # Ajustar el tamaño de las etiquetas del eje x
plt.legend(title='Predicción')
plt.tight_layout()  # Ajustar el layout para que las etiquetas no se corten

plt.show()

# %%
grouped.describe()
# Out:
# prediction        NEG         NEU        POS       %NEG       %POS       %NEU
# count       48.000000   48.000000  48.000000  48.000000  48.000000  48.000000
# mean        53.958333   85.145833  12.020833  35.668612   8.004189  56.327199
# std         16.192930   23.601289   4.795785   5.370935   2.652225   5.515863
# min         29.000000   43.000000   3.000000  25.203252   3.125000  39.814815
# 25%         42.250000   70.500000   9.000000  31.578947   5.863554  53.346292
# 50%         50.500000   80.000000  11.000000  35.472432   7.568293  56.186224
# 75%         64.500000   96.250000  14.250000  38.891560   9.740334  59.836066
# max         96.000000  163.000000  25.000000  50.925926  13.392857  66.187050

# %% [markdown]
# ### Organizaciones y personas más mencionadas

# %%
import spacy

# Cargar el modelo de Spacy para el idioma que necesites (por ejemplo, español)
nlp = spacy.load("es_core_news_sm")

# Función para extraer entidades de tipo persona de un texto usando Spacy
def extract_person_entities(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "PER" and len(ent.text.split()) >= 2]

def extract_org_entities(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ == "ORG" and len(ent.text.split()) >= 2]

# Aplicar la función a cada fila de la columna "text" y guardar los resultados en una nueva columna
df_filtr["person_entities"] = df_filtr["text"].apply(extract_person_entities)
df_filtr["org_entities"] = df_filtr["text"].apply(extract_org_entities)

# %%
# Convertir la lista de personas en una sola lista para contar las ocurrencias de cada persona
all_persons = [person for sublist in df_filtr["person_entities"] for person in sublist]
# Contar las ocurrencias de cada persona
person_counts = pd.Series(all_persons).value_counts()
# Mostrar las personas más mencionadas
person_counts.head(20)
# Out:
# Gabriel Boric                  627
# Marco Antonio Ávila            280
# Sebastián Piñera               234
# Raúl Figueroa                  232
# Michelle Bachelet              173
# Donald Trump                   151
# Qué Pasa                       139
# Joe Biden                      127
# Camila Vallejo                 118
# Carlos Díaz                    104
# Enrique Paris                  102
# Ignacio Sánchez                100
# Ennio Vivaldi                   98
# José Antonio Kast               89
# Presidente Sebastián Piñera     89
# Raúl Cordero                    85
# Presidente Boric                79
# Pedro Castillo                  79
# Izkia Siches                    78
# Daniel Jadue                    77
# Name: count, dtype: int64

# %%
# Convertir la lista de personas en una sola lista para contar las ocurrencias de cada persona
all_orgs = [org for sublist in df_filtr["org_entities"] for org in sublist]
# Contar las ocurrencias de cada persona
orgs_counts = pd.Series(all_orgs).value_counts()
# Mostrar las personas más mencionadas
orgs_counts.head(20)
# Out:
# Universidad de Chile                        1665
# Universidad Católica                         506
# Colegio de Profesores                        387
# Región Metropolitana                         357
# Convención Constitucional                    238
# Frente Amplio                                221
# Organización Mundial de la Salud             214
# Universidad de Oxford                        182
# Universidad de Concepción                    172
# Partido Republicano                          161
# Universidad de Valparaíso                    143
# Universidad Johns Hopkins                    141
# La Tercera PM                                138
# Universidad de Harvard                       132
# Instituto Nacional                           131
# Partido Comunista                            126
# Instituto de Salud Pública                   116
# Pontificia Universidad Católica de Chile     115
# Unión Europea                                112
# Consejo de Rectores                          103
# Name: count, dtype: int64

# %% [markdown]
# # 3- Método para clasificar las noticias
#
# ## Según su comuna

# %%
# !pip install -q -U google-generativeai

# %%
GOOGLE_API_KEY = "YOUR_API_KEY"

# Importamos el paquete recien instalado
import google.generativeai as genai
import json
import time

genai.configure(api_key = GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')

def obtener_comuna(text):
    time.sleep(2)
    question = '''A partir de este texto, dame una respuesta en formato json
{"Comuna": Comuna del evento principal}
No incluyas nada más de texto en la respuesta (Tampoco "la comuna es" o el país). 
Si no se incluye en el texto, entonces dame la comuna de la institución principal que se nombra o en caso extremo, la comuna o ciudad más probable según la información.
NUNCA dejes la respuesta como null
Texto: ''' + text + ". \n Repito, NUNCA DEJES LA RESPUESTA COMO NULL"
    try:
        return json.loads(model.generate_content(question).text)["Comuna"]
    except Exception as e:  # Catch more general exceptions
        print(f"Unexpected error: {e}")
        if(str(e) == '429 Resource has been exhausted (e.g. check quota).'):
            return "NO QUOTA"
        return "NO"

# %%
df_filtr['Comuna'] = df_filtr['text'].apply(obtener_comuna)

# %%
df_filtr.loc[df_filtr['Comuna'] == 'NO', 'Comuna'] = df_filtr.loc[df_filtr['Comuna'] == 'NO', 'text'].apply(obtener_comuna)
# Out:
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: list indices must be integers or slices, not str
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'Comuna'
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# ...
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).

# %%
df_filtr.loc[df_filtr['Comuna'] == 'NO QUOTA', 'Comuna'] = df_filtr.loc[df_filtr['Comuna'] == 'NO QUOTA', 'text'].apply(obtener_comuna)
# Out:
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 'Comuna'
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: Expecting value: line 1 column 1 (char 0)
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 'NoneType' object is not subscriptable
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).
# Unexpected error: 429 Resource has been exhausted (e.g. check quota).

# %% [markdown]
# ## Según su región

# %%
import json

with open('cities.json', 'r', encoding='utf-8') as file:
    regiones = json.load(file)

def encontrar_region_por_comuna(text):
    for region in regiones:
        for comuna in region['communes']:
            if comuna['name'].lower() == text.lower():
                return region['name']
    return "NO"

# %%
df_filtr['Region'] = df_filtr['Comuna'].apply(encontrar_region_por_comuna)
df_filtr['Region']
# Out:
# 0                              NO
# 1                              NO
# 2       Metropolitana de Santiago
# 3                              NO
# 4       Metropolitana de Santiago
#                   ...
# 7249                           NO
# 7250    Metropolitana de Santiago
# 7251    Metropolitana de Santiago
# 7252                     Los Ríos
# 7253    Metropolitana de Santiago
# Name: Region, Length: 7254, dtype: object

# %%
len(df_filtr[df_filtr['Region'] != 'NO'])
# Out:
# 3038

# %%
df_filtr.to_csv("datos_filtrados.csv")

# %%
df_filtr = pd.read_csv('./datos_filtrados.csv')
df_filtr
# Out:
#       Unnamed: 0        date country media_outlet  \
# 0              0  2020-01-01   chile    latercera
# 1              1  2020-01-01   chile    latercera
# 2              2  2020-01-01   chile    latercera
# 3              3  2020-01-01   chile    latercera
# 4              4  2020-01-01   chile    latercera
# ...          ...         ...     ...          ...
# 7249        7249  2021-01-27   chile    latercera
# 7250        7250  2021-01-27   chile    latercera
# 7251        7251  2021-12-28   chile    latercera
# 7252        7252  2021-12-27   chile    latercera
# 7253        7253  2021-12-22   chile    latercera
#
#                                                   title  \
# 0     Descubren gigantesco cráter por el impacto de ...
# 1     Así era el pez que hace 375 millones de años c...
# 2     Llamados a protestas marcan la antesala de la ...
# 3     Desde el Cruch descartan nuevo aplazamiento de...
# 4     La nueva sociedad de médicos chilenos formados...
# ...                                                 ...
# 7249  Memorias de una pesadilla: cuando la U ya tuvo...
# 7250  Demandan a U. de Chile por $ 8.429 millones po...
# 7251  Balance del Mineduc: 162 colegios del país cer...
# 7252  Boric ordena “La Moneda chica” y se devela ase...
# 7253  “La Moneda chica”: Boric reubica centro de ope...
#
#                                                    text  \
# 0     Un campo de manchas negras vidriosas, esparcid...
# 1     Una investigación sobre peces fosilizados del ...
# 2     A horas de que se rinda la Prueba de Selección...
# 3     Esta mañana, Aldo Valle, rector de la Universi...
# 4     "Soy médico general, chileno, y actualmente tr...
# ...                                                 ...
# 7249  Coquimbo Unido vence a Unión Española y da un ...
# 7250  Luego de que 29 de agosto de 2019 una profesor...
# 7251  Salvo contadas excepciones, el año escolar lle...
# 7252  Son quienes estarán con el presidente electo G...
# 7253  Cuando Gabriel Boric arribó esta mañana a la n...
#
#                                                     url  relevancia  \
# 0     https://www.latercera.com/que-pasa/noticia/des...           1
# 1     https://www.latercera.com/que-pasa/noticia/asi...           1
# 2     https://www.latercera.com/nacional/noticia/lla...           1
# 3     https://www.latercera.com/nacional/noticia/des...           1
# 4     https://www.latercera.com/nacional/noticia/la-...           1
# ...                                                 ...         ...
# 7249  https://www.latercera.com/la-tercera-pm/notici...           1
# 7250  https://www.latercera.com/la-tercera-pm/notici...           2
# 7251  https://www.latercera.com/la-tercera-pm/notici...           5
# 7252  https://www.latercera.com/la-tercera-pm/notici...           1
# 7253  https://www.latercera.com/la-tercera-pm/notici...           1
#
#      month_year prediction     score  \
# 0       2020-01        NEU  0.991257
# 1       2020-01        NEG  0.796142
# 2       2020-01        NEG  0.992838
# 3       2020-01        NEU  0.994395
# 4       2020-01        NEG  0.996074
# ...         ...        ...       ...
# 7249    2021-01        NEG  0.998829
# 7250    2021-01        NEG  0.802090
# 7251    2021-12        NEG  0.998475
# 7252    2021-12        NEU  0.997870
# 7253    2021-12        NEU  0.990284
#
#                                         person_entities  \
# 0                                                    []
# 1     ['Thomas Stewart', 'Neil Shubin', 'Ihna Yoo', ...
# 2     ['Aldo Valle', 'Ignacio Sánchez', 'admisión di...
# 3     ['Aldo Valle', 'https://www.latercera.com/naci...
# 4     ['Rolando Santos', 'Izkia Siches', 'Rolando Sa...
# ...                                                 ...
# 7249  ['Unión Española', 'Rafael Dudamel', 'Soinca B...
# 7250  ['daño moral y emergente', 'Manuel de Salas', ...
# 7251  ['Raúl Figueroa', 'Alejandra Grebe', 'Javiera ...
# 7252  ['Gabriel Boric', 'Michelle Bachelet', 'Pedro ...
# 7253  ['Gabriel Boric', 'Obispo Salas', 'Santa Isabe...
#
#                                            org_entities            Comuna  \
# 0                ['Universidad Tecnológica de Nanjing']                NO
# 1                                                    []           Chicago
# 2     ['Asamblea Coordinadora de Estudiantes Secunda...          Santiago
# 3     ['Universidad de Valparaíso', 'Consejo de Rect...                NO
# 4     ['Servicio de Atención Primaria de Urgencia', ...          Pudahuel
# ...                                                 ...               ...
# 7249  ['Universidad de Chile', 'partido de definició...  no se especifica
# 7250  ['Universidad de Chile', '26 Juzgado Civil de'...          Santiago
# 7251  ['Superintendencia de Educación', 'Región Metr...         Lo Espejo
# 7252        ['jefa de gabinete', 'CS Antonia Orellana']          Valdivia
# 7253  ['Universidad de Chile', 'Instituto de Estudio...          Santiago
#
#                          Region
# 0                            NO
# 1                            NO
# 2     Metropolitana de Santiago
# 3                            NO
# 4     Metropolitana de Santiago
# ...                         ...
# 7249                         NO
# 7250  Metropolitana de Santiago
# 7251  Metropolitana de Santiago
# 7252                   Los Ríos
# 7253  Metropolitana de Santiago
#
# [7254 rows x 15 columns]

# %% [markdown]
# # 4- Porcentaje de exactitud del método

# %% [markdown]
# ## ¿Cuáles son las limitaciones de su método?

# %% [markdown]
# # Distribución de las noticias según su comuna y región

# %%
df_filtr['Comuna'] = df_filtr['Comuna'].str.lower()
conteo_region = df_filtr[df_filtr['Region'] != 'NO'].groupby('Region')['prediction'].value_counts().unstack(fill_value=0)
conteo_region.index = conteo_region.index.values
conteo_region
# Out:
# prediction                                 NEG   NEU  POS
# Aisén del General Carlos Ibáñez del Campo    0     2    0
# Antofagasta                                 20    30    6
# Araucanía                                   50    63    8
# Arica y Parinacota                           5    12    0
# Atacama                                     21    20    3
# Biobío                                      32    64    7
# Coquimbo                                    16    18    4
# Libertador General Bernardo O’Higgins       19    16    3
# Los Lagos                                    7    16    0
# Los Ríos                                    11    27   10
# Magallanes y de la Antártica Chilena        12    14    1
# Maule                                       21    28    7
# Metropolitana de Santiago                  755  1236  171
# Tarapacá                                     7     4    2
# Valparaíso                                 102   165   12
# Ñuble                                        6     5    0

# %%
conteo_region.plot(kind='bar', stacked=False, figsize=(10, 10), align='center', color={'POS': '#70D453', 'NEG': '#EB5A5A', 'NEU': '#536DD4'})  # Ajustar el parámetro align
plt.title('Histograma por Región y Predicción')
plt.xlabel('Región')
plt.ylabel('Cantidad')
plt.xticks(rotation=80)  # Rotar las etiquetas del eje x para mayor legibilidad
plt.legend(title='Predicción')  # Mostrar leyenda con título
plt.tight_layout()  # Ajustar el diseño del gráfico
plt.show()

# %% [markdown]
# geopandas: https://geopandas.org/en/stable/
#
# Kepler: https://kepler.gl/

# %%
import geopandas as gpd

# %%
SHAPEFILE=r'./shape/comunas.shp' #shapefile de las regiones y comunas de Chile
# fuente: https://www.bcn.cl/siit/mapas_vectoriales

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Cargar los datos geoespaciales de las regiones de Chile
chile_regions = gpd.read_file(SHAPEFILE, encoding='utf-8')

# %%
chile_regions
# Out:
#      objectid     shape_leng  dis_elec  cir_sena  cod_comuna  codregion  \
# 0          48  170038.624165        16         8        6204          6
# 1          29  125730.104795        15         8        6102          6
# 2          30   63026.084422        15         8        6103          6
# 3          31   89840.903562        15         8        6104          6
# 4          78  122626.493264        23        11        9121          9
# ..        ...            ...       ...       ...         ...        ...
# 341       255  130240.555805        19        10       16305         16
# 342       253  311061.932415        19        10       16304         16
# 343       245  159257.906431        19        10       16303         16
# 344       243  157467.049667        19        10       16104         16
# 345       242  276848.826499        19        10       16302         16
#
#        st_area_sh     st_length_                                    Region  \
# 0    9.685774e+08  206184.271675  Región del Libertador Bernardo O'Higgins
# 1    4.157446e+08  151911.576827  Región del Libertador Bernardo O'Higgins
# 2    1.448565e+08   76355.326122  Región del Libertador Bernardo O'Higgins
# 3    3.256572e+08  108874.623150  Región del Libertador Bernardo O'Higgins
# 4    6.990727e+08  156680.410681                    Región de La Araucanía
# ..            ...            ...                                       ...
# 341  8.751006e+08  160459.137929                           Región de Ñuble
# 342  2.393007e+09  388109.613857                           Región de Ñuble
# 343  7.638173e+08  195593.933727                           Región de Ñuble
# 344  1.044405e+09  196962.664313                           Región de Ñuble
# 345  2.764576e+09  346671.611064                           Región de Ñuble
#
#           Comuna      Provincia  \
# 0      marchigüe  Cardenal Caro
# 1        codegua      Cachapoal
# 2         coinco      Cachapoal
# 3       coltauco      Cachapoal
# 4       cholchol         Cautín
# ..           ...            ...
# 341  san nicolás        Punilla
# 342   san fabián        Punilla
# 343       ñiquén        Punilla
# 344    el carmen          Ñuble
# 345     coihueco        Punilla
#
#                                               geometry  value
# 0    POLYGON ((-7992818.789 -4056669.319, -7992731....      8
# 1    POLYGON ((-7831651.813 -4022443.109, -7831596....      4
# 2    POLYGON ((-7892616.357 -4060673.364, -7892621....      6
# 3    POLYGON ((-7906457.717 -4051723.734, -7906266....      7
# 4    POLYGON ((-8121756.186 -4645860.295, -8121644....     10
# ..                                                 ...    ...
# 341  POLYGON ((-8041950.854 -4349201.562, -8041735....      9
# 342  POLYGON ((-7931328.549 -4363544.179, -7931320....      5
# 343  POLYGON ((-8026032.185 -4319505.012, -8025933....      4
# 344  POLYGON ((-7986315.104 -4415272.935, -7986309....      8
# 345  POLYGON ((-7927593.046 -4435376.051, -7927638....      8
#
# [346 rows x 13 columns]

# %%
df_filtr['Comuna'] = df_filtr['Comuna'].str.lower()
conteo_predictions = df_filtr[df_filtr['Region'] != 'NO'].groupby('Comuna')['prediction'].value_counts().unstack(fill_value=0)

# %%
chile_regions['Comuna'] = chile_regions['Comuna'].str.lower()
resultado_merge = pd.merge(chile_regions, conteo_predictions, on='Comuna', how='left')
resultado_merge = resultado_merge.dropna(subset=['NEG'])

# %%
# Crear una figura y ejes
fig, ax = plt.subplots(figsize=(10, 10))
# Reemplaza 'variable' con el nombre de la columna de tu DataFrame que contiene la variable a visualizar
# Reemplaza 'cmap' con el mapa de colores que desees usar
# Reemplaza 'legend' con True si deseas mostrar la leyenda
# Dibujar el mapa de Chile
chile_regions.plot(ax=ax, color='lightgrey', edgecolor='black')

# Colorear las regiones según una variable específica
# Reemplaza 'variable' con el nombre de la columna de tu DataFrame que contiene la variable a visualizar
# Reemplaza 'cmap' con el mapa de colores que desees usar
# Reemplaza 'legend' con True si deseas mostrar la leyenda
# Reemplaza 'vmin' y 'vmax' con los valores mínimo y máximo de tu variable para normalizar los colores

#chile_regions.plot(ax=ax, column='variable', cmap='coolwarm', legend=True, vmin=0, vmax=100)

resultado_merge.plot(ax=ax, column="NEG", cmap='coolwarm', legend=True, vmin=1, vmax=10)

# Añadir título y etiquetas de los ejes
plt.title('Mapa de Chile')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
#plt.xlim([-0.9, 0])

# Mostrar el mapa
plt.show()

# %%
# Crear una figura y ejes
fig, ax = plt.subplots(figsize=(10, 10))

chile_regions[chile_regions['Region'] == 'Región Metropolitana de Santiago'].plot(ax=ax, color='lightgrey', edgecolor='black')

resultado_merge[chile_regions['Region'] == 'Región Metropolitana de Santiago'].plot(ax=ax, column="NEG", cmap='coolwarm', legend=True, vmin=1, vmax=10)

# Añadir título y etiquetas de los ejes
plt.title('Mapa de Chile')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
#plt.xlim([-0.9, 0])

# Mostrar el mapa
plt.show()
# Out:
# C:\Users\gluar\anaconda3\lib\site-packages\geopandas\geodataframe.py:1475: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
